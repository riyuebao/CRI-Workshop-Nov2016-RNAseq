# %% [markdown]
# # AMIA 2016 Annual Symposium Workshop (WG13)
#
# ## Automated and Scalable Cloud-based RNA-Seq Data Analysis, Part I
#
#
# Riyue Bao, Ph.D.
# Center for Research Informatics,
# The University of Chicago.
# November 13, 2016
#
# ***
#
# ## Objective
#
# * Learn the applications and basic workflow of RNA-Seq analysis
# * Learn the concept of cloud computing and scalable pipeline design
# * Practice the automated RNAseq analysis pipeline
# * Explore every analysis step
# * Practice commonly used bioinformatics tools
#
# ***
#
# ## Dataset
#
# The test datasets used in this workshop are from
# Fog. et al. 2015. Loss of PRDM11 promotes MYC-driven lymphomagenesis. Blood, 125(8):1272-81
# <http://www.bloodjournal.org/content/125/8/1272.long?sso-checked=true>
#
# ***
#
# ## Workflow
#
# Download analysis pipeline from [Github](https://github.com/riyuebao/CRI-Workshop-Nov2016-RNAseq).
#
# ***
#
# ## Run pipeline
#
# ```{bash}
# ubuntu@ip-172-31-21-233:~$ pwd
# /home/ubuntu
# ubuntu@ip-172-31-21-233:~$ cd dev/
# chipseq/ rnaseq/
# ubuntu@ip-172-31-21-233:~$ cd dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test/
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ ls -al
# total 32
# drwxrwxr-x 3 ubuntu ubuntu 4096 Oct 13 14:38 .
# drwxrwxr-x 8 ubuntu ubuntu 4096 Oct 13 00:33 ..
# drwxrwxr-x 4 ubuntu ubuntu 4096 Oct 13 14:38 archive
# -rwxrwx--- 1 ubuntu ubuntu  865 Oct 12 22:27 Build_RNAseq.DLBC.sh
# -rw-rw---- 1 ubuntu ubuntu  997 Oct 13 14:37 DLBC.metadata.txt
# -rw-rw---- 1 ubuntu ubuntu 5170 Oct 13 00:11 DLBC.pipeline.yaml
# -rwxrwx--- 1 ubuntu ubuntu  378 Oct 13 00:34 Submit_RNAseq.DLBC.sh
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ ./Build_RNAseq.DLBC.sh
# START Thu Oct 13 14:39:16 UTC 2016
# END Thu Oct 13 14:39:16 UTC 2016
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ ls -al -t
# total 40
# -rw-rw-r-- 1 ubuntu ubuntu 2265 Oct 13 14:39 Build_RNAseq.DLBC.10-13-2016_14:39:16.log
# drwxrwxr-x 6 ubuntu ubuntu 4096 Oct 13 14:39 myProject
# -rwxrwx--- 1 ubuntu ubuntu  414 Oct 13 14:39 Submit_RNAseq.DLBC.sh
# drwxrwxr-x 4 ubuntu ubuntu 4096 Oct 13 14:39 .
# drwxrwxr-x 4 ubuntu ubuntu 4096 Oct 13 14:38 archive
# -rw-rw---- 1 ubuntu ubuntu  997 Oct 13 14:37 DLBC.metadata.txt
# drwxrwxr-x 8 ubuntu ubuntu 4096 Oct 13 00:33 ..
# -rw-rw---- 1 ubuntu ubuntu 5170 Oct 13 00:11 DLBC.pipeline.yaml
# -rwxrwx--- 1 ubuntu ubuntu  865 Oct 12 22:27 Build_RNAseq.DLBC.sh
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ ./Submit_RNAseq.DLBC.sh &
# [1] 2986
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ jobs
# [1]+  Running                 ./Submit_RNAseq.DLBC.sh &
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$ ll -t
# total 40
# drwxrwxr-x 4 ubuntu ubuntu 4096 Oct 13 14:39 ./
# -rw------- 1 ubuntu ubuntu    0 Oct 13 14:39 bds.pid.2988
# -rw-rw-r-- 1 ubuntu ubuntu    0 Oct 13 14:39 Run_RNAseq.DLBC.10-13-2016_14:39:31.log.err
# -rw-rw-r-- 1 ubuntu ubuntu    0 Oct 13 14:39 Run_RNAseq.DLBC.10-13-2016_14:39:31.log.out
# -rw-rw-r-- 1 ubuntu ubuntu 2265 Oct 13 14:39 Build_RNAseq.DLBC.10-13-2016_14:39:16.log
# drwxrwxr-x 6 ubuntu ubuntu 4096 Oct 13 14:39 myProject/
# -rwxrwx--- 1 ubuntu ubuntu  414 Oct 13 14:39 Submit_RNAseq.DLBC.sh*
# drwxrwxr-x 4 ubuntu ubuntu 4096 Oct 13 14:38 archive/
# -rw-rw---- 1 ubuntu ubuntu  997 Oct 13 14:37 DLBC.metadata.txt
# drwxrwxr-x 8 ubuntu ubuntu 4096 Oct 13 00:33 ../
# -rw-rw---- 1 ubuntu ubuntu 5170 Oct 13 00:11 DLBC.pipeline.yaml
# -rwxrwx--- 1 ubuntu ubuntu  865 Oct 12 22:27 Build_RNAseq.DLBC.sh*
# ubuntu@ip-172-31-21-233:~/dev/rnaseq/CRI-Workshop-Nov2016-RNAseq/test$
#
# ```
